# %%
from util.plot_utils import *

# %%
from pathlib import Path

# %%
import torch
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from pathlib import Path, PurePath

# %%
fields = ('loss','class_error','loss_bbox','loss_giou','mAP')  # <-- put the items of interest here

# %%
laprop83 = Path.cwd()/'s1-training-results/s1-training-Aug-03-2020'  # <--- set path to your args.output_dir

# %%
plot_logs(laprop83, fields)
# Out:
# plot_utils.py::plot_logs info: logs param expects a list argument, converted to list[Path].

# %%
s1log = Path.cwd()/'s1-training-results/s1-training-Jul-31-2020-3' #<--- you can do multiple dirs and put them into a list and pass in as well...

# %%
laprop=Path.cwd()/'s1-training-results/s1-training-Aug-01-2020-2'

# %%
s1matcher = Path.cwd()/'s1-training-results/s1-training-Aug-01-2020-1'

# %%
quad_logs = [laprop83,s1matcher, s1log, laprop]

# %%
plot_logs(quad_logs,fields)

# %%
plot_logs(dual_logs, fields)
